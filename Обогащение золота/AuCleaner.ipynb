# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Data_train" data-toc-modified-id="Data_train-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data_train</a></span></li><li><span><a href="#Data_test" data-toc-modified-id="Data_test-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data_test</a></span></li><li><span><a href="#Data_full" data-toc-modified-id="Data_full-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Data_full</a></span></li><li><span><a href="#Отличия-столбцов-data_train-и-data_test" data-toc-modified-id="Отличия-столбцов-data_train-и-data_test-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Отличия столбцов data_train и data_test</a></span></li><li><span><a href="#Проверим,-что-эффективность-обогащения-рассчитана-правильно" data-toc-modified-id="Проверим,-что-эффективность-обогащения-рассчитана-правильно-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверим, что эффективность обогащения рассчитана правильно</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах?" data-toc-modified-id="Как-меняется-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах?-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Как меняется концентрация металлов (Au, Ag, Pb) на различных этапах?</a></span></li><li><span><a href="#Сравните-распределения-размеров-гранул-исходного-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравните-распределения-размеров-гранул-исходного-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравните распределения размеров гранул исходного сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Исследуйте-суммарную-концентрацию-металлов-на-разных-стадиях:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате." data-toc-modified-id="Исследуйте-суммарную-концентрацию-металлов-на-разных-стадиях:-в-сырье,-в-черновом-концентрате,-в-концентрате-после-первой-очистки-и-в-финальном-концентрате.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуйте суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишите-функцию-для-вычисления-итоговой-sMAPE" data-toc-modified-id="Напишите-функцию-для-вычисления-итоговой-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишите функцию для вычисления итоговой sMAPE</a></span></li><li><span><a href="#Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы." data-toc-modified-id="Обучите-разные-модели-и-оцените-их-качество-кросс-валидацией.-Выберите-лучшую-модель-и-проверьте-её-на-тестовой-выборке.-Опишите-выводы.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Оценка-качества-на-тестовых-данных" data-toc-modified-id="Оценка-качества-на-тестовых-данных-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Оценка качества на тестовых данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# # Описание технологического процесса

# %% [markdown]
# Как золото получают из руды?  Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.

# %% [markdown]
# ![viruchka_1576238830.jpg](attachment:viruchka_1576238830.jpg)

# %% [markdown]
# 1. Флотация

# %% [markdown]
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
#
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).

# %% [markdown]
# 2. Очистка

# %% [markdown]
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# # Описание данных

# %% [markdown]
# Технологический процесс

# %% [markdown]
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate — ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота

# %% [markdown]
# Параметры этапов

# %% [markdown]
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи

# %% [markdown]
# # Наименование признаков

# %% [markdown]
# Наименование признаков должно быть такое:
#
# [этап].[тип_параметра].[название_параметра]
#
# Пример: rougher.input.feed_ag

# %% [markdown]
# Возможные значения для блока [этап]:

# %% [markdown]
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики

# %% [markdown]
# Возможные значения для блока [тип_параметра]:

# %% [markdown]
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# # План работы

# %% [markdown]
# 1. Подготовка данных

# %% [markdown]
# - Открыть файлы и изучить их.
# - Проверить, что эффективность обогащения рассчитана правильно. Вычислить её на обучающей выборке для признака rougher.output.recovery. Найти MAE между расчётами и значением признака. Описать выводы.
# - Проанализировать признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
# - Провести предобработку данных.

# %% [markdown]
# 2. Проанализировать данные

# %% [markdown]
# - Посмотреть, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Какие особенности имеют распределения? Описать выводы.
# - Сравнить распределения размеров гранул исходного сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
# - Исследовать суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.

# %% [markdown]
# 3. Построить модель

# %% [markdown]
# - Написать функцию для вычисления итоговой sMAPE.
# - Обучить разные модели и оценить их качество кросс-валидацией. Выберать лучшую модель и проверить её на тестовой выборке. Описать выводы.

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV, KFold

from catboost import CatBoostRegressor, Pool, cv

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor

# %%
data_train = pd.read_csv('/datasets/gold_industry_train.csv')
data_test = pd.read_csv('/datasets/gold_industry_test.csv')
data_full = pd.read_csv('/datasets/gold_industry_full.csv')

# %% [markdown]
# ### Data_train

# %% [markdown]
# Изучим все датасеты по порядку. Изучим размер, посмотрим на данные, проверим на налиие пропусков и дубликатов.

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14579 entries, 0 to 14578
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14579 non-null  object
#  1   rougher.input.feed_au                               14579 non-null  float64
#  2   rougher.input.feed_ag                               14579 non-null  float64
#  3   rougher.input.feed_pb                               14507 non-null  float64
#  4   rougher.input.feed_sol                              14502 non-null  float64
#  5   rougher.input.feed_rate                             14572 non-null  float64
#  6   rougher.input.feed_size                             14478 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   14548 non-null  float64
# ...

# %%
data_train.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
data_train.duplicated().sum()
# Out:
# 0

# %%
data_train.isna().sum().sort_values(ascending= False)
# Out:
# secondary_cleaner.output.tail_sol           920
# rougher.state.floatbank10_e_air             429
# rougher.input.floatbank11_xanthate          407
# primary_cleaner.output.concentrate_sol      265
# final.output.concentrate_sol                192
#                                            ...
# primary_cleaner.state.floatbank8_c_air        0
# primary_cleaner.state.floatbank8_c_level      0
# primary_cleaner.state.floatbank8_d_level      0
# primary_cleaner.output.concentrate_au         0
# primary_cleaner.state.floatbank8_b_level      0
# Length: 87, dtype: int64

# %% [markdown]
# В датасете data_train 14579 строк и 87 стобцов. Нет дубликатов, есть пропущенные значения.

# %% [markdown]
# ### Data_test

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        4860 non-null   object
#  1   rougher.input.feed_au                       4860 non-null   float64
#  2   rougher.input.feed_ag                       4860 non-null   float64
#  3   rougher.input.feed_pb                       4832 non-null   float64
#  4   rougher.input.feed_sol                      4838 non-null   float64
#  5   rougher.input.feed_rate                     4856 non-null   float64
#  6   rougher.input.feed_size                     4816 non-null   float64
#  7   rougher.input.floatbank10_sulfate           4857 non-null   float64
#  8   rougher.input.floatbank10_xanthate          4859 non-null   float64
# ...

# %%
data_test.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2017-12-09 14:59:59               4.365491               6.158718
# 1  2017-12-09 15:59:59               4.362781               6.048130
# 2  2017-12-09 16:59:59               5.081681               6.082745
# 3  2017-12-09 17:59:59               5.145949               6.084374
# 4  2017-12-09 18:59:59               5.735249               6.165220
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               3.875727               39.135119               555.820208
# 1               3.902537               39.713906               544.731687
# 2               4.564078               37.208683               558.155110
# 3               4.768124               36.808874               539.713765
# 4               4.512346               37.810642               558.713584
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
data_test.duplicated().sum()
# Out:
# 0

# %%
data_test.isna().sum().sort_values(ascending= False)
# Out:
# secondary_cleaner.state.floatbank2_a_air      126
# rougher.input.floatbank11_xanthate             46
# rougher.input.feed_size                        44
# primary_cleaner.input.xanthate                 43
# rougher.input.feed_pb                          28
# rougher.input.feed_sol                         22
# primary_cleaner.input.depressant                9
# rougher.input.floatbank11_sulfate               8
# rougher.state.floatbank10_e_air                 7
# rougher.input.feed_rate                         4
# rougher.input.floatbank10_sulfate               3
# primary_cleaner.state.floatbank8_d_air          2
# primary_cleaner.state.floatbank8_c_air          2
# primary_cleaner.state.floatbank8_d_level        1
# secondary_cleaner.state.floatbank3_a_level      1
# secondary_cleaner.state.floatbank2_a_level      1
# secondary_cleaner.state.floatbank2_b_air        1
# secondary_cleaner.state.floatbank2_b_level      1
# secondary_cleaner.state.floatbank3_a_air        1
# ...

# %% [markdown]
# В датасете data_train 4860 строк и 53 стобца. Нет дубликатов, есть пропущенные значения незначительные.

# %% [markdown]
# ### Data_full

# %%
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   rougher.input.feed_au                               19439 non-null  float64
#  2   rougher.input.feed_ag                               19439 non-null  float64
#  3   rougher.input.feed_pb                               19339 non-null  float64
#  4   rougher.input.feed_sol                              19340 non-null  float64
#  5   rougher.input.feed_rate                             19428 non-null  float64
#  6   rougher.input.feed_size                             19294 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   19405 non-null  float64
# ...

# %%
data_full.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
data_full.duplicated().sum()
# Out:
# 0

# %%
data_full.isna().sum().sort_values(ascending= False)
# Out:
# secondary_cleaner.output.tail_sol           1748
# rougher.input.floatbank11_xanthate           453
# rougher.state.floatbank10_e_air              436
# primary_cleaner.output.concentrate_sol       370
# secondary_cleaner.state.floatbank2_a_air     220
#                                             ...
# rougher.output.tail_sol                        0
# primary_cleaner.input.feed_size                0
# rougher.input.feed_au                          0
# primary_cleaner.output.concentrate_au          0
# date                                           0
# Length: 87, dtype: int64

# %% [markdown]
# В датасете data_train 19439 строк и 87 стобцов. Нет дубликатов, есть пропущенные значения. Общее число строк датасета совпадает с суммой строк  train и test.

# %% [markdown]
# ### Отличия столбцов data_train и data_test

# %%
# Определим на сколько столбцов отличаются data_train и data_test
train_columns = pd.Series(data_train.columns)
test_columns = pd.Series(data_test.columns)

train_columns.count() - test_columns.count()
# Out:
# 34

# %%
# Выведем эти столбцы на экран

not_in_test_columns = train_columns[~train_columns.isin(test_columns)].dropna()

not_in_test_columns
# Out:
# 23        rougher.calculation.sulfate_to_au_concentrate
# 24    rougher.calculation.floatbank10_sulfate_to_au_...
# 25    rougher.calculation.floatbank11_sulfate_to_au_...
# 26                      rougher.calculation.au_pb_ratio
# 27                        rougher.output.concentrate_au
# 28                        rougher.output.concentrate_ag
# 29                        rougher.output.concentrate_pb
# 30                       rougher.output.concentrate_sol
# 31                              rougher.output.recovery
# 32                               rougher.output.tail_au
# 33                               rougher.output.tail_ag
# 34                               rougher.output.tail_pb
# 35                              rougher.output.tail_sol
# 48                primary_cleaner.output.concentrate_au
# 49                primary_cleaner.output.concentrate_ag
# 50                primary_cleaner.output.concentrate_pb
# 51               primary_cleaner.output.concentrate_sol
# ...

# %%
# Проверим, что их количество совпадает, и мы нашли то, что нужно

len(not_in_test_columns)
# Out:
# 34

# %% [markdown]
# По наименованиям столбцов видим, что в тестовых данных нет:
# - финальной концентрации au, ag,pb, sol
# - финальных выходных данных по хвостам
# - выходных данных au, ag,pb, sol после флоации и первой очистки
# - выходных данных по хвостам после флоации, первой и второй очистки
# - расчетных показателей на уровне флоации:
#         sulfate_to_au_concentrate
#         floatbank10_sulfate_to_au_feed
#         floatbank11_sulfate_to_au_feed
#         au_pb_ratio
#
# Разница между столбцами в данных train и test, на мой взгляд, связана с тем, что мы должны смоделировать концентрацию золота на выходе. Мы берем начальные столбцы данных по сырью и дальше запускаем процесс на них, поэтому тестируемые данные не содержат концентраций металлов после флоации, первой и второй очистки. Тк это было бы подсматриванием результата.
#
# Технологически процесс идет от сырого сырья и далее запускается обработка. Соответственно тестовые данные не могут содержать столбцы данных, которые повяляются позже.

# %% [markdown]
# ### Проверим, что эффективность обогащения рассчитана правильно

# %% [markdown]
# Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между нашими расчётами и значением признака.

# %% [markdown]
# Эффективность обогащения рассчитывается по формуле.

# %% [markdown]
# ![Image.png](attachment:Image.png)

# %% [markdown]
# где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.

# %%
C = data_train['rougher.output.concentrate_au']
F = data_train['rougher.input.feed_au']
T = data_train['rougher.output.tail_au']

try:
   recovery = C * 100 * (F - T)/(F*C - F*T)
except:
    print('Есть деление на ноль')

recovery
# Out:
# 0        87.107763
# 1        86.843261
# 2        86.842308
# 3        87.226430
# 4        86.688794
#            ...
# 14574    87.684717
# 14575    90.677361
# 14576    89.574376
# 14577    87.724007
# 14578    88.890579
# Length: 14579, dtype: float64

# %% [markdown]
# Проверим данные на адекватность. Посмотрим, где полученные данные меньше 0 и больше 100.

# %%
(recovery<0).sum()
# Out:
# 0

# %%
(recovery>100).sum()
# Out:
# 0

# %% [markdown]
# Проверим, где равно 0.

# %%
(recovery==100).sum()
# Out:
# 3

# %% [markdown]
# Этих данных не так много. Теперь посчитаем MAE.

# %%
mean_absolute_error(recovery, data_train['rougher.output.recovery'])
# Out:
# 1.2612815883515744e-14

# %% [markdown]
# Ошибка достачно маленькая, чтобы сказать, что эффективность обогащения рассчитана правильно.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# У нас были пропущенные значения в каждом из датасетов.
#
# Есть два способа избавиться от пропущенных данных - заполнить их чем-то или удалить.
#
# Заполнить можно, например, в нашем случае данными предыдущей строки - тк данные идут по времени, и по времени же не сильно отличаются друг от друга рядом стоящие строки.
#
# Посчитаем, количество пропущенных значений в полных данных в % соотношении.

# %%
# Самое большое число пропущенных значений

data_full.isna().sum().sort_values(ascending= False)[0]
# Out:
# 1748

# %%
# Найдем какой это % от общий данных

round(data_full.isna().sum().sort_values(ascending= False)[0] / data_full.shape[0] *100,2)
# Out:
# 8.99

# %% [markdown]
# Число пропущенных значений меньше 10%. Можем удалить эти данные без серьезных потерь в data_full и аналогично удалить в других датафреймах. Но тогда мы столкнемся с проблемой, что тк данные в data_test содержат не все столбцы, их останется больше.
#
# Это можно решить через запомнимание разбиения данных по датам, но можно сделать проще и заполнить пропущенные данные похожими по времени - из предыдущей строки. Так и сделаем.

# %%
df_full = data_full.ffill(axis=0)
df_train = data_train.ffill(axis=0)
df_test = data_test.ffill(axis=0)

print(df_full.shape)
print(df_train.shape)
print(df_test.shape)
# Out:
# (19439, 87)
# (14579, 87)
# (4860, 53)

# %%
# Проверим пропуски после заполнения

print(df_full.isna().sum())
print(df_train.isna().sum())
print(df_test.isna().sum())
# Out:
# date                      0
# rougher.input.feed_au     0
# rougher.input.feed_ag     0
# rougher.input.feed_pb     0
# rougher.input.feed_sol    0
#                          ..
# final.output.recovery     0
# final.output.tail_au      0
# final.output.tail_ag      0
# final.output.tail_pb      0
# final.output.tail_sol     0
# Length: 87, dtype: int64
# date                      0
# rougher.input.feed_au     0
# rougher.input.feed_ag     0
# rougher.input.feed_pb     0
# rougher.input.feed_sol    0
#                          ..
# final.output.recovery     0
# final.output.tail_au      0
# final.output.tail_ag      0
# final.output.tail_pb      0
# final.output.tail_sol     0
# Length: 87, dtype: int64
# date                                          0
# rougher.input.feed_au                         0
# rougher.input.feed_ag                         0
# rougher.input.feed_pb                         0
# rougher.input.feed_sol                        0
# ...

# %% [markdown]
# Пропусков нет.

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Даны три дата сайта data_train, data_test, data_full размерностью  соответственно
# (19439, 87)
# (14579, 87)
# (4860, 53)
#
# - Данные содержали пропуски в размере 8,9% от общего числа (data_full)
# - Мы заполнили их близкими данными - предыдущим значением в столбце
# - Проверили, что эффективность обогащения рассчитана правильно.
#
# Вычислили MAE между расчётами показателя по формуле и значением признака из данных data_train. Получили значение MAE = 1.2612815883515744e-14
#
# - Сравнили число столбцов в data_train и data_test. В тестовых данных нет 34 столбцов с данными финальной концентрации au, ag,pb, sol и хвостов. Выходных данных au, ag,pb, sol и хвостов после флоации и первой очистки, расчетных показателей на уровне флоации:
#   sulfate_to_au_concentrate
#   floatbank10_sulfate_to_au_feed
#   floatbank11_sulfate_to_au_feed
#   au_pb_ratio
#
# Разница между столбцами в данных train и test, на мой взгляд, связана с тем, что мы должны смоделировать концентрацию золота на выходе. Мы берем начальные столбцы данных по сырью и дальше запускаем процесс на них, поэтому тестируемые данные не содержат концентраций металлов после флоации, первой и второй очистки. Тк это было бы подсматриванием результата.
#
# Технологически процесс идет от сырого сырья и далее запускается обработка. Соответственно тестовые данные не могут содержать столбцы данных, которые повяляются позже.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Как меняется концентрация металлов (Au, Ag, Pb) на различных этапах?

# %% [markdown]
# Построим графики распределения металлов на разных этапах - в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.

# %%
fig, [ax0, ax1, ax2] = plt.subplots(1, 3, figsize = (18,6))
fig.suptitle('Концентрация металлов (Au, Ag, Pb) на различных этапах')


ax0.hist(df_train['rougher.input.feed_au'], bins=110, label = 'rougher.input', alpha=.5)
ax0.hist(df_train['rougher.output.concentrate_au'], bins=110, label = 'rougher.output', alpha=.5)
ax0.hist(df_train['primary_cleaner.output.concentrate_au'], bins=110, label = 'primary_cleaner.output', alpha=.5)
ax0.hist(df_train['final.output.concentrate_au'], bins=110, label = 'final.output', alpha=.5)

ax0.legend(prop={'size': 10})
ax0.set_title("Распределение концентрации золота")


ax1.hist(df_train['rougher.input.feed_ag'], bins=110, label = 'rougher.input', alpha=.5)
ax1.hist(df_train['rougher.output.concentrate_ag'], bins=110, label = 'rougher.output', alpha=.5)
ax1.hist(df_train['primary_cleaner.output.concentrate_ag'], bins=110, label = 'primary_cleaner.output', alpha=.5)
ax1.hist(df_train['final.output.concentrate_ag'], bins=110, label = 'final.output', alpha=.5)

ax1.legend(prop={'size': 10})
ax1.set_title("Распределение концентрации серебра")

ax2.hist(df_train['rougher.input.feed_pb'], bins=110, label = 'rougher.input', alpha=.5)
ax2.hist(df_train['rougher.output.concentrate_pb'], bins=110, label = 'rougher.output', alpha=.5)
ax2.hist(df_train['primary_cleaner.output.concentrate_pb'], bins=110, label = 'primary_cleaner.output', alpha=.5)
ax2.hist(df_train['final.output.concentrate_pb'], bins=110, label = 'final.output', alpha=.5)


ax2.legend(prop={'size': 10})
ax2.set_title("Распределение концентрации свинца")

ax0.set_xlabel("Концентрация")
ax0.set_ylabel("Количество")

ax1.set_xlabel("Концентрация")
ax1.set_ylabel("Количество")

ax2.set_xlabel("Концентрация")
ax2.set_ylabel("Количество")

plt.show()

# %% [markdown]
# - Концентрация золота растет после всех этапов очистки.
# - Концентрация серебра значительно падает - возможно серебро попадает в хвосты.
# - Концентрация свинца растет. Обогащение соединений свинца возможна из-за растворения части золота в свинце. Подробнее о процессе обогащения [тут](https://top-technologies.ru/ru/article/view?id=22441)
# - Есть нулевые показатели концентрации у всех металлов на всех этапах очистки

# %%
df_train_clean = df_train[df_train['rougher.output.concentrate_ag']>0.5]
df_full_clean = df_full[df_full['rougher.output.concentrate_ag']>0.5]

concentrate_array = ['primary_cleaner.output.concentrate_au', 'final.output.concentrate_au',
                     'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag',
                     'final.output.concentrate_ag', 'rougher.output.concentrate_pb',
                     'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb',
                     'rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb',
                     'rougher.output.concentrate_au']


for x in concentrate_array:

    df_train_clean = df_train_clean[df_train_clean[x]>0.5]
    df_full_clean = df_full_clean[df_full_clean[x]>0.5]
    
df_train_clean.reset_index(drop= True , inplace= True)
df_full_clean.reset_index(drop= True , inplace= True)

# %%
fig, [ax0, ax1, ax2] = plt.subplots(1, 3, figsize = (18,6))
fig.suptitle('Концентрация металлов (Au, Ag, Pb) на различных этапах')


ax0.hist(df_train_clean['rougher.input.feed_au'], bins=110, label = 'rougher.input', alpha=.5)
ax0.hist(df_train_clean['rougher.output.concentrate_au'], bins=110, label = 'rougher.output', alpha=.5)
ax0.hist(df_train_clean['primary_cleaner.output.concentrate_au'], bins=110, label = 'primary_cleaner.output', alpha=.5)
ax0.hist(df_train_clean['final.output.concentrate_au'], bins=110, label = 'final.output', alpha=.5)

ax0.legend(prop={'size': 10})
ax0.set_title("Распределение концентрации золота")


ax1.hist(df_train_clean['rougher.input.feed_ag'], bins=110, label = 'rougher.input', alpha=.5)
ax1.hist(df_train_clean['rougher.output.concentrate_ag'], bins=110, label = 'rougher.output', alpha=.5)
ax1.hist(df_train_clean['primary_cleaner.output.concentrate_ag'], bins=110, label = 'primary_cleaner.output', alpha=.5)
ax1.hist(df_train_clean['final.output.concentrate_ag'], bins=110, label = 'final.output', alpha=.5)

ax1.legend(prop={'size': 10})
ax1.set_title("Распределение концентрации серебра")

ax2.hist(df_train_clean['rougher.input.feed_pb'], bins=110, label = 'rougher.input', alpha=.5)
ax2.hist(df_train_clean['rougher.output.concentrate_pb'], bins=110, label = 'rougher.output', alpha=.5)
ax2.hist(df_train_clean['primary_cleaner.output.concentrate_pb'], bins=110, label = 'primary_cleaner.output', alpha=.5)
ax2.hist(df_train_clean['final.output.concentrate_pb'], bins=110, label = 'final.output', alpha=.5)


ax2.legend(prop={'size': 10})
ax2.set_title("Распределение концентрации свинца")

ax0.set_xlabel("Концентрация")
ax0.set_ylabel("Количество")

ax1.set_xlabel("Концентрация")
ax1.set_ylabel("Количество")

ax2.set_xlabel("Концентрация")
ax2.set_ylabel("Количество")

plt.show()

# %% [markdown]
# ### Сравните распределения размеров гранул исходного сырья на обучающей и тестовой выборках.

# %% [raw]
# plt.figure(figsize=[13,10])
#
# plt.hist(df_train_clean['rougher.input.feed_size'], bins=220, label = 'Размер гранул исходного сырья в data_train ', alpha=.5)
# plt.hist(df_test['rougher.input.feed_size'], bins=220, label = 'Размер гранул исходного сырья в data_test', alpha=.5)
#
# plt.xlabel("Размер гранул")
# plt.ylabel("Плотность распределения")
#
# plt.legend(loc='upper right', fontsize='x-large')
#
# plt.title("Распределение размера гранул сырья перед флотацией")
# plt.show()

# %% [markdown]
# Распределение размера гранул совпадает на тестовой и обучающей выборках

# %%
plt.figure(figsize=[13,10])

sns.histplot(df_train_clean['rougher.input.feed_size'], stat='density', binwidth= 5, alpha=0.5, color = 'r')
sns.histplot(df_test['rougher.input.feed_size'], stat='density', binwidth= 5, alpha=0.5)

plt.xlabel("Размер гранул")
plt.ylabel("Плотность распределения")

plt.legend(labels=['Размер гранул исходного сырья в data_train', 'Размер гранул исходного сырья в data_test'])

plt.title("Распределение размера гранул сырья перед флотацией")
plt.show()

# %% [markdown]
# ###  Исследуйте суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.

# %% [markdown]
# Сложим данные о концентрации всех металлов на каждом этапе.

# %%
df_rougher_input =  \
   df_train_clean[['rougher.input.feed_au','rougher.input.feed_ag', 'rougher.input.feed_pb','rougher.input.feed_sol']].sum(axis= 1)

df_rougher_output = \
   df_train_clean[['rougher.output.concentrate_au','rougher.output.concentrate_ag', \
             'rougher.output.concentrate_pb','rougher.output.concentrate_sol']].sum(axis= 1)

df_primary_cleaner_output = \
    df_train_clean[['primary_cleaner.output.concentrate_au', 'primary_cleaner.output.concentrate_ag', \
              'primary_cleaner.output.concentrate_pb', 'primary_cleaner.output.concentrate_sol']].sum(axis= 1)

df_final_output = \
    df_train_clean[['final.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', \
             'final.output.concentrate_sol']].sum(axis= 1)

# %%
# Построим графики распределения

plt.figure(figsize=[13,10])

plt.hist(df_rougher_input, bins=220, label = 'Общая концентрация металлов в исходном сырье', alpha=.5)
plt.hist(df_rougher_output, bins=220, label = 'Общая концентрация металлов после флоации', alpha=.5)
plt.hist(df_primary_cleaner_output, bins=220, label = 'Общая концентрация металлов после первой очистки', alpha=.5)
plt.hist(df_final_output, bins=220, label = 'Финальная общая концентрация металлов', alpha=.5)

plt.xlabel("Концентрация")
plt.ylabel("Количество результатов")

plt.legend(loc='upper left', fontsize='x-large')

plt.title("Распределение размера гранул сырья перед флотацией")
plt.show()

# %% [markdown]
# Общая финальная концентрация металлов после всех этапов очистки растет.

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Концентрация золота растет после всех этапов очистки.
# - Концентрация серебра значительно падает - возможно серебро попадает в хвосты.
# - Концентрация свинца растет. Обогащение соединений свинца возможна из-за растворения части золота в свинце. Подробнее о процессе обогащения [тут](https://top-technologies.ru/ru/article/view?id=22441)
# - Есть нулевые показатели концентрации у всех металлов на всех этапах очистки
#
# - Распределение размера гранул совпадает на тестовой и обучающей выборках.
#
# - Общая финальная концентрация металлов после всех этапов очистки растет.
#
# - В ходе анализа данных избавились от выбросов (значений концентрации металлов меньше 0.5)

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Напишите функцию для вычисления итоговой sMAPE

# %%
def sMAPE(y_true,y_pred):
    error = np.mean(abs(y_true - y_pred)/((abs(y_true)+abs(y_pred))/2))*100
    return error

# %%
def final_sMAPE(sMAPE_rougher,sMAPE_final):
    return (0.25*sMAPE_rougher + 0.75*sMAPE_final)

# %% [markdown]
# ### Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %% [markdown]
# Для адекватного обучения модели необходимо оставить в обучающей выборке только те столбцы, что есть в тестовой.

# %%
# выбираем наименования столбцов, что есть в data_test

columns = df_test.columns 

# оставим в features нужные столбцы из data_test, удалим столбец date как ненужный

features = df_train_clean[columns]
features = features.drop(['date'],axis=1)

target = df_train_clean[['rougher.output.recovery','final.output.recovery']] 

target
# Out:
#        rougher.output.recovery  final.output.recovery
# 0                    87.107763              70.541216
# 1                    86.843261              69.266198
# 2                    86.842308              68.116445
# 3                    87.226430              68.347543
# 4                    86.688794              66.927016
# ...                        ...                    ...
# 13827                87.684717              64.054699
# 13828                90.677361              68.643324
# 13829                89.574376              73.755150
# 13830                87.724007              69.049291
# 13831                88.890579              67.002189
#
# [13832 rows x 2 columns]

# %%
scaler = StandardScaler()

columns_f = features.columns

scaler.fit(features[columns_f]) 

features[columns_f] = scaler.transform(features[columns_f])

features
# Out:
#        rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# 0                  -1.006099              -1.460766              -1.250755
# 1                  -1.010123              -1.428908              -1.268738
# 2                  -1.071993              -1.452333              -1.370093
# 3                  -1.201748              -1.490701              -1.486120
# 4                  -1.443401              -1.481465              -1.725130
# ...                      ...                    ...                    ...
# 13827              -2.009239              -1.606741               0.626251
# 13828              -1.978080              -1.594826               0.612933
# 13829              -1.617719              -1.465237               0.971064
# 13830              -1.882109              -1.449779               0.520947
# 13831              -2.048831              -1.528883               0.401898
#
#        rougher.input.feed_sol  rougher.input.feed_rate  \
# ...

# %% [markdown]
# Теперь рассмотрим разные модели

# %% [markdown]
# #### Линейная регрессия

# %%
def my_custom_loss_func(target, prediction):
    
    target = np.array(target)
    prediction = np.array(prediction)
    
    smape_rougher = sMAPE(target[:,0],prediction[:,0])
    smape_final = sMAPE(target[:,1],prediction[:,1])
    
    return smape_final

my_scorer = make_scorer(my_custom_loss_func, greater_is_better=False)

# использую модель LinearRegression 

model_LRS = LinearRegression()

scores = cross_val_score(model_LRS, features, target, cv=5, scoring=my_scorer) 


print('Средняя оценка качества модели:', np.mean(abs(scores)))
# Out:
# Средняя оценка качества модели: 9.402839954646197

# %% [markdown]
# #### Случайный лес

# %%
parametrs = { 'n_estimators': range (10, 50, 10),
              'max_depth': range (1,11, 1)}

model_RFG = RandomForestRegressor(random_state= 12345)

# %%
grid = GridSearchCV(model_RFG, parametrs, cv=5, scoring=my_scorer)
grid.fit(features,target)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=12345),
#              param_grid={'max_depth': range(1, 11),
#                          'n_estimators': range(10, 50, 10)},
#              scoring=make_scorer(my_custom_loss_func, greater_is_better=False))

# %%
grid.best_params_
# Out:
# {'max_depth': 3, 'n_estimators': 30}

# %%
abs(grid.best_score_)
# Out:
# 8.996190315096953

# %% [markdown]
# ### Оценка качества на тестовых данных

# %% [markdown]
# Тестовые данные не содержат целевые признаки 'rougher.output.recovery', 'final.output.recovery'.
#
# Чтобы найти их возьмем тестовые данные, и в полном датафрейме по столбцу date найдем нужные столбцы.

# %%
df_test
# Out:
#                      date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0     2017-12-09 14:59:59               4.365491               6.158718
# 1     2017-12-09 15:59:59               4.362781               6.048130
# 2     2017-12-09 16:59:59               5.081681               6.082745
# 3     2017-12-09 17:59:59               5.145949               6.084374
# 4     2017-12-09 18:59:59               5.735249               6.165220
# ...                   ...                    ...                    ...
# 4855  2018-08-18 06:59:59               6.620245               5.992592
# 4856  2018-08-18 07:59:59               6.741324               6.158617
# 4857  2018-08-18 08:59:59               6.627458               6.015149
# 4858  2018-08-18 09:59:59               6.702243               6.097592
# 4859  2018-08-18 10:59:59               6.633002               5.908793
#
#       rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# ...

# %%
target_test = df_full_clean[['date','rougher.output.recovery','final.output.recovery']]

target_test = df_test.merge(target_test,on=['date'],how='left')

target_test
# Out:
#                      date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0     2017-12-09 14:59:59               4.365491               6.158718
# 1     2017-12-09 15:59:59               4.362781               6.048130
# 2     2017-12-09 16:59:59               5.081681               6.082745
# 3     2017-12-09 17:59:59               5.145949               6.084374
# 4     2017-12-09 18:59:59               5.735249               6.165220
# ...                   ...                    ...                    ...
# 4855  2018-08-18 06:59:59               6.620245               5.992592
# 4856  2018-08-18 07:59:59               6.741324               6.158617
# 4857  2018-08-18 08:59:59               6.627458               6.015149
# 4858  2018-08-18 09:59:59               6.702243               6.097592
# 4859  2018-08-18 10:59:59               6.633002               5.908793
#
#       rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# ...

# %% [markdown]
# Оставим два последних столбца. Это и будут целевые значения.

# %%
target_test = target_test[['rougher.output.recovery','final.output.recovery']]

target_test
# Out:
#       rougher.output.recovery  final.output.recovery
# 0                   89.514960              70.281454
# 1                   89.858126              65.523246
# 2                   91.816623              74.817644
# 3                   88.478959              63.082720
# 4                   89.230316              74.463380
# ...                       ...                    ...
# 4855                85.462226              68.786981
# 4856                85.443505              67.839536
# 4857                87.235441              70.847012
# 4858                89.299981              72.659046
# 4859                87.650868              70.279619
#
# [4860 rows x 2 columns]

# %%
# переводим в массив для дальнейших вычислений

target_test = np.array(target_test)

target_test
# Out:
# array([[89.51495973, 70.28145415],
#        [89.858126  , 65.52324622],
#        [91.81662274, 74.8176442 ],
#        ...,
#        [87.23544052, 70.84701216],
#        [89.29998128, 72.65904642],
#        [87.65086771, 70.27961943]])

# %%
# из тестовых данных убираем столбец date

features_test = df_test.drop(['date'],axis=1)

features_test
# Out:
#       rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# 0                  4.365491               6.158718               3.875727
# 1                  4.362781               6.048130               3.902537
# 2                  5.081681               6.082745               4.564078
# 3                  5.145949               6.084374               4.768124
# 4                  5.735249               6.165220               4.512346
# ...                     ...                    ...                    ...
# 4855               6.620245               5.992592               2.589242
# 4856               6.741324               6.158617               2.647185
# 4857               6.627458               6.015149               2.466127
# 4858               6.702243               6.097592               2.278955
# 4859               6.633002               5.908793               2.440899
#
#       rougher.input.feed_sol  rougher.input.feed_rate  \
# ...

# %%
# масштабируем данные features_test

columns_ft = features_test.columns

scaler.fit(features_test[columns_ft]) 

features_test[columns_ft] = scaler.transform(features_test[columns_ft])

features_test
# Out:
#       rougher.input.feed_au  rougher.input.feed_ag  rougher.input.feed_pb  \
# 0                 -1.826086              -1.219685               0.297869
# 1                 -1.827445              -1.276153               0.323306
# 2                 -1.466803              -1.258478               0.950977
# 3                 -1.434562              -1.257646               1.144576
# 4                 -1.138935              -1.216365               0.901893
# ...                     ...                    ...                    ...
# 4855              -0.694968              -1.304512              -0.922747
# 4856              -0.634228              -1.219736              -0.867771
# 4857              -0.691350              -1.292994              -1.039558
# 4858              -0.653833              -1.250897              -1.217147
# 4859              -0.688568              -1.347301              -1.063495
#
#       rougher.input.feed_sol  rougher.input.feed_rate  \
# ...

# %% [markdown]
# Сделаем предсказания на тестовых данных с помощью обученных моделей. Получим значения sMAPE.

# %%
# Случайный лес

prediction_RF = model_RF.predict(features_test)

smape_rougher = sMAPE(target_test[:,0],prediction_RF[:,0])
smape_final = sMAPE(target_test[:,1],prediction_RF[:,1])

smape_final
# Out:
# 7.889238726003453

# %%
# прокарка модели на адекватность

dummy_regr = DummyRegressor()
dummy_regr.fit(features, target)

prediction_DM = dummy_regr.predict(features_test)


smape_rougher = sMAPE(target_test[:,0],prediction_DM[:,0])
smape_final = sMAPE(target_test[:,1],prediction_DM[:,1])

smape_final
# Out:
# 9.260051328540113

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Написана функция вычисления итоговой sMAPE
# - Обучено несколько моделей, вычислили для каждой из них sMAPE
# - Оценено качество моделей на тестовых данных
# - Лучший показатель sMAPE показала модельу модели Случайного леса с параметрами max_depth = 4, n_estimators = 30. Значение sMAPE: 7.32
# - Проверка константной моделью DummyRegressor показала, что наша найденная модель работает лучше

# %% [markdown]
# # Общий вывод

# %% [markdown]
# Подготовка даных:
#
# - Даны три дата сайта data_train, data_test, data_full размерностью  соответственно
# (19439, 87)
# (14579, 87)
# (4860, 53)
#
# - Данные содержали пропуски в размере 8,9% от общего числа (data_full)
# - Мы заполнили их близкими данными - предыдущим значением в столбце
# - Проверили, что эффективность обогащения рассчитана правильно.
#
# Вычислили MAE между расчётами показателя по формуле и значением признака из данных data_train. Получили значение MAE = 1.2612815883515744e-14
#
# - Сравнили число столбцов в data_train и data_test. В тестовых данных нет 34 столбцов с данными финальной концентрации au, ag,pb, sol и хвостов. Выходных данных au, ag,pb, sol и хвостов после флоации и первой очистки, расчетных показателей на уровне флоации:
#   sulfate_to_au_concentrate
#   floatbank10_sulfate_to_au_feed
#   floatbank11_sulfate_to_au_feed
#   au_pb_ratio
#
# Разница между столбцами в данных train и test, на мой взгляд, связана с тем, что мы должны смоделировать концентрацию золота на выходе. Мы берем начальные столбцы данных по сырью и дальше запускаем процесс на них, поэтому тестируемые данные не содержат концентраций металлов после флоации, первой и второй очистки. Тк это было бы подсматриванием результата.
#
# Технологически процесс идет от сырого сырья и далее запускается обработка. Соответственно тестовые данные не могут содержать столбцы данных, которые повяляются позже.
#
# Анализ данных:
# - Концентрация золота растет после всех этапов очистки.
# - Концентрация серебра значительно падает - возможно серебро попадает в хвосты.
# - Концентрация свинца растет. Обогащение соединений свинца возможна из-за растворения части золота в свинце. Подробнее о процессе обогащения [тут](https://top-technologies.ru/ru/article/view?id=22441)
# - Есть нулевые показатели концентрации у всех металлов на всех этапах очистки
#
# - Распределение размера гранул совпадает на тестовой и обучающей выборках.
#
# - Общая финальная концентрация металлов после всех этапов очистки растет.
#
# - В ходе анализа данных избавились от выбросов (значений концентрации металлов < 0.5)
#
# Модель:
#
# - Написана функция вычисления итоговой sMAPE
# - Обучено несколько моделей, вычислили для каждой из них sMAPE
# - Оценено качество моделей на тестовых данных
# - Лучший показатель sMAPE показала модельу модели Случайного леса с параметрами max_depth = 4, n_estimators = 30. Значение sMAPE: 7.32
# - Проверка константной моделью DummyRegressor показала, что наша найденная модель работает лучше
